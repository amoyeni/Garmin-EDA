# %%
import garminconnect
import pandas as pd
import numpy as np
import datetime
from sqlalchemy import create_engine, text
from dotenv import load_dotenv
import os

load_dotenv()

email = os.getenv("email")
password = os.getenv("garminpassword")\

garmin = garminconnect.Garmin(email, password)
garmin.login()
garmin.display_name
# Out:
# '5f3dc0bc-4916-4755-894b-cca99162502b'

# %%
import json
date = '2025-06-12'
def getdata(date):
    return garmin.get_sleep_data(date)

data = getdata(date)

# %%
def safe_dataframe(data, key):
    """
    Safely extracts a nested value from a dictionary and returns a DataFrame.
    Handles missing keys, None values, scalars, or poorly structured dicts.
    """
    nested = data.get(key)

    if not nested:
        return pd.DataFrame()

    # If a dict but all values are scalars (not dicts/lists), skip it
    if isinstance(nested, dict):
        if all(not isinstance(v, (dict, list)) for v in nested.values()):
            return pd.DataFrame()
        return pd.DataFrame([nested])  
    
    # If list of struct objects or list
    if isinstance(nested, list):
        return pd.DataFrame(nested)

    # return empty 
    return pd.DataFrame()

# %%
user = os.getenv("user")
password = os.getenv("password")
host = os.getenv("host")
port = os.getenv("port")
dbname = os.getenv("dbname")

DATABASE_URL = f"postgresql://{user}:{password}@{host}:{port}/{dbname}"
engine = create_engine(DATABASE_URL)

try:
    with engine.connect() as conn:
        result = result = conn.execute(text("SELECT version();"))
        for row in result:
            print("Connected to:", row[0])
except Exception as e:
    print(" Connection failed:", e)
# Out:
# Connected to: PostgreSQL 17.4 on aarch64-unknown-linux-gnu, compiled by gcc (GCC) 13.2.0, 64-bit

# %%
def getgeneral(data):
        return safe_dataframe(data, 'dailySleepDTO')

df_general = getgeneral(data)
print(df_general.head())
# Out:
#               id  userProfilePK calendarDate  sleepTimeSeconds  \
# 0  1749687960000       80897268   2025-06-12             24660
#
#    napTimeSeconds  sleepWindowConfirmed sleepWindowConfirmationType  \
# 0               0                  True    enhanced_confirmed_final
#
#    sleepStartTimestampGMT  sleepEndTimestampGMT  sleepStartTimestampLocal  \
# 0           1749687960000         1749713640000             1749691560000
#
#    ...  lowestRespirationValue highestRespirationValue awakeCount  \
# 0  ...                    10.0                    20.0          1
#
#   avgSleepStress ageGroup  sleepScoreFeedback  sleepScoreInsight  \
# 0           19.0    ADULT       POSITIVE_DEEP               NONE
#
#    sleepScorePersonalizedInsight  \
# 0                  NOT_AVAILABLE
#
#                                          sleepScores  sleepVersion
# 0  {'totalDuration': {'qualifierKey': 'FAIR', 'op...             2
#
# [1 rows x 38 columns]

# %%
def getsleepHR(data):
    
    df = safe_dataframe(data, 'sleepHeartRate')
    if 'startGMT' in df.columns:
        df['startGMT'] = pd.to_datetime(df['startGMT'], unit='ms')
    
    return df

df_sleephr = getsleepHR(data)
print(df_sleephr.head())
# Out:
#    value            startGMT
# 0     82 2025-06-12 00:26:00
# 1     82 2025-06-12 00:28:00
# 2     79 2025-06-12 00:30:00
# 3     76 2025-06-12 00:32:00
# 4     78 2025-06-12 00:34:00

# %%
def getsleep_wakeHR(date):
    if df_sleephr.empty:
        return {'Date':date,'sleepHR': None, 'wakeHR': None}

    df_sorted = df_sleephr.sort_values('startGMT').reset_index(drop=True)

    sleep_hr = df_sorted.loc[0, 'value']
    wake_hr = df_sorted.loc[len(df_sorted) - 1, 'value']

    row = pd.DataFrame([{
        'date': date,
        'sleep_hr': sleep_hr,
        'wake_hr': wake_hr
    }])

    return row



print(getsleep_wakeHR(date))
# Out:
#          date  sleep_hr  wake_hr
# 0  2025-06-12        82       64

# %%
current_date = datetime.date.today()
end_date = datetime.date(2024, 6, 19)

df_sleepwakehr = pd.DataFrame()

while current_date >= end_date:
    data = getdata(current_date)
    df_general = getgeneral(data)
    df_sleephr = getsleepHR(data)
    df_sleep_wake = getsleep_wakeHR(current_date)
    print(df_sleep_wake)
    if not df_sleephr.empty:
        df_sleep_wake = getsleep_wakeHR(current_date)
        df_sleepwakehr = pd.concat([df_sleepwakehr, df_sleep_wake], ignore_index=True)

    current_date -= datetime.timedelta(days=1)

df_sleepwakehr['date'] = pd.to_datetime(df_sleepwakehr['date']).dt.date
df_sleepwakehr.head()
# Out:
#          date  sleep_hr  wake_hr
# 0  2025-07-14        56       50
#          date  sleep_hr  wake_hr
# 0  2025-07-13        64       47
#          date  sleep_hr  wake_hr
# 0  2025-07-12        61       45
#          date  sleep_hr  wake_hr
# 0  2025-07-11        55       50
#          date  sleep_hr  wake_hr
# 0  2025-07-10        56       45
#          date  sleep_hr  wake_hr
# 0  2025-07-09        61       56
#          date  sleep_hr  wake_hr
# 0  2025-07-08        60       45
#          date  sleep_hr  wake_hr
# 0  2025-07-07      70.0     58.0
#          date  sleep_hr  wake_hr
# 0  2025-07-06        60       52
#          date  sleep_hr  wake_hr
# 0  2025-07-05        69       48
#          date  sleep_hr  wake_hr
# 0  2025-07-04        72       46
# {'Date': datetime.date(2025, 7, 3), 'sleepHR': None, 'wakeHR': None}
#          date  sleep_hr  wake_hr
# 0  2025-07-02        54       49
#          date  sleep_hr  wake_hr
# 0  2025-07-01        65       50
#          date  sleep_hr  wake_hr
# 0  2025-06-30        55       46
#          date  sleep_hr  wake_hr
# 0  2025-06-29        63       57
#          date  sleep_hr  wake_hr
# 0  2025-06-28        62       52
#          date  sleep_hr  wake_hr
# 0  2025-06-27        70       49
#          date  sleep_hr  wake_hr
# 0  2025-06-26        55       44
#          date  sleep_hr  wake_hr
# 0  2025-06-25        58       51
#          date  sleep_hr  wake_hr
# 0  2025-06-24        52       47
#          date  sleep_hr  wake_hr
# 0  2025-06-23        51       56
#          date  sleep_hr  wake_hr
# 0  2025-06-22        69       54
#          date  sleep_hr  wake_hr
# 0  2025-06-21        65       51
#          date  sleep_hr  wake_hr
# 0  2025-06-20        62       55
#          date  sleep_hr  wake_hr
# 0  2025-06-19        78       54
#          date  sleep_hr  wake_hr
# 0  2025-06-18        70       55
#          date  sleep_hr  wake_hr
# 0  2025-06-17        64       57
#          date  sleep_hr  wake_hr
# 0  2025-06-16        67       52
#          date  sleep_hr  wake_hr
# 0  2025-06-15        79       58
#          date  sleep_hr  wake_hr
# 0  2025-06-14        62       52
#          date  sleep_hr  wake_hr
# 0  2025-06-13        64       58
#          date  sleep_hr  wake_hr
# 0  2025-06-12        82       64
#          date  sleep_hr  wake_hr
# 0  2025-06-11        72       56
#          date  sleep_hr  wake_hr
# 0  2025-06-10        63       59
#          date  sleep_hr  wake_hr
# 0  2025-06-09        68       65
#          date  sleep_hr  wake_hr
# 0  2025-06-08        74       55
#          date  sleep_hr  wake_hr
# 0  2025-06-07        63       49
#          date  sleep_hr  wake_hr
# 0  2025-06-06        72       52
#          date  sleep_hr  wake_hr
# 0  2025-06-05        68       57
#          date  sleep_hr  wake_hr
# 0  2025-06-04        74       51
#          date  sleep_hr  wake_hr
# 0  2025-06-03        70       56
#          date  sleep_hr  wake_hr
# 0  2025-06-02        69       50
#          date  sleep_hr  wake_hr
# 0  2025-06-01        80       59
#          date  sleep_hr  wake_hr
# 0  2025-05-31        67       59
#          date  sleep_hr  wake_hr
# 0  2025-05-30        73       62
#          date  sleep_hr  wake_hr
# 0  2025-05-29        69       55
#          date  sleep_hr  wake_hr
# 0  2025-05-28        77       62
#          date  sleep_hr  wake_hr
# 0  2025-05-27        69       66
#          date  sleep_hr  wake_hr
# 0  2025-05-26        69       62
#          date  sleep_hr  wake_hr
# 0  2025-05-25        61       55
#          date  sleep_hr  wake_hr
# 0  2025-05-24        70       57
#          date  sleep_hr  wake_hr
# 0  2025-05-23        56       54
#          date  sleep_hr  wake_hr
# 0  2025-05-22        71       60
#          date  sleep_hr  wake_hr
# 0  2025-05-21        58       75
#          date  sleep_hr  wake_hr
# 0  2025-05-20        68       56
#          date  sleep_hr  wake_hr
# 0  2025-05-19        68       53
#          date  sleep_hr  wake_hr
# 0  2025-05-18        73       54
#          date  sleep_hr  wake_hr
# 0  2025-05-17        73       51
#          date  sleep_hr  wake_hr
# 0  2025-05-16        67       52
#          date  sleep_hr  wake_hr
# 0  2025-05-15        71       51
#          date  sleep_hr  wake_hr
# 0  2025-05-14        73       48
#          date  sleep_hr  wake_hr
# 0  2025-05-13        69       69
#          date  sleep_hr  wake_hr
# 0  2025-05-12        66       65
#          date  sleep_hr  wake_hr
# 0  2025-05-11        90       74
#          date  sleep_hr  wake_hr
# 0  2025-05-10        73       55
#          date  sleep_hr  wake_hr
# 0  2025-05-09        62       63
#          date  sleep_hr  wake_hr
# 0  2025-05-08        60       56
#          date  sleep_hr  wake_hr
# 0  2025-05-07        66       55
#          date  sleep_hr  wake_hr
# 0  2025-05-06        69       56
#          date  sleep_hr  wake_hr
# 0  2025-05-05        71       52
#          date  sleep_hr  wake_hr
# 0  2025-05-04        58       56
# {'Date': datetime.date(2025, 5, 3), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 5, 2), 'sleepHR': None, 'wakeHR': None}
#          date  sleep_hr  wake_hr
# 0  2025-05-01        68       65
#          date  sleep_hr  wake_hr
# 0  2025-04-30        58       52
#          date  sleep_hr  wake_hr
# 0  2025-04-29        66       45
#          date  sleep_hr  wake_hr
# 0  2025-04-28        68       58
#          date  sleep_hr  wake_hr
# 0  2025-04-27        70       49
#          date  sleep_hr  wake_hr
# 0  2025-04-26        57       53
#          date  sleep_hr  wake_hr
# 0  2025-04-25        67       58
#          date  sleep_hr  wake_hr
# 0  2025-04-24        73       59
#          date  sleep_hr  wake_hr
# 0  2025-04-23        69       50
#          date  sleep_hr  wake_hr
# 0  2025-04-22        70       56
#          date  sleep_hr  wake_hr
# 0  2025-04-21        66       61
#          date  sleep_hr  wake_hr
# 0  2025-04-20        72       52
#          date  sleep_hr  wake_hr
# 0  2025-04-19        69       52
#          date  sleep_hr  wake_hr
# 0  2025-04-18        70       51
#          date  sleep_hr  wake_hr
# 0  2025-04-17        61       56
#          date  sleep_hr  wake_hr
# 0  2025-04-16        66       53
#          date  sleep_hr  wake_hr
# 0  2025-04-15        76       58
#          date  sleep_hr  wake_hr
# 0  2025-04-14        50       60
#          date  sleep_hr  wake_hr
# 0  2025-04-13        73       51
#          date  sleep_hr  wake_hr
# 0  2025-04-12        61       55
#          date  sleep_hr  wake_hr
# 0  2025-04-11        60       49
#          date  sleep_hr  wake_hr
# 0  2025-04-10        61       55
#          date  sleep_hr  wake_hr
# 0  2025-04-09        64       51
#          date  sleep_hr  wake_hr
# 0  2025-04-08        57       52
#          date  sleep_hr  wake_hr
# 0  2025-04-07        62       50
#          date  sleep_hr  wake_hr
# 0  2025-04-06        65       52
#          date  sleep_hr  wake_hr
# 0  2025-04-05        67       51
#          date  sleep_hr  wake_hr
# 0  2025-04-04        66       51
#          date  sleep_hr  wake_hr
# 0  2025-04-03        57       51
#          date  sleep_hr  wake_hr
# 0  2025-04-02        69       49
#          date  sleep_hr  wake_hr
# 0  2025-04-01        65       45
#          date  sleep_hr  wake_hr
# 0  2025-03-31        60       47
#          date  sleep_hr  wake_hr
# 0  2025-03-30        63       60
#          date  sleep_hr  wake_hr
# 0  2025-03-29        63       53
#          date  sleep_hr  wake_hr
# 0  2025-03-28        64       46
#          date  sleep_hr  wake_hr
# 0  2025-03-27        75       50
#          date  sleep_hr  wake_hr
# 0  2025-03-26        57       54
#          date  sleep_hr  wake_hr
# 0  2025-03-25        52       50
#          date  sleep_hr  wake_hr
# 0  2025-03-24        58       63
#          date  sleep_hr  wake_hr
# 0  2025-03-23        67       53
#          date  sleep_hr  wake_hr
# 0  2025-03-22        65       50
#          date  sleep_hr  wake_hr
# 0  2025-03-21        60       50
#          date  sleep_hr  wake_hr
# 0  2025-03-20        78       57
#          date  sleep_hr  wake_hr
# 0  2025-03-19        64       49
#          date  sleep_hr  wake_hr
# 0  2025-03-18        51       53
#          date  sleep_hr  wake_hr
# 0  2025-03-17        63       50
#          date  sleep_hr  wake_hr
# 0  2025-03-16        60       52
#          date  sleep_hr  wake_hr
# 0  2025-03-15        75       52
#          date  sleep_hr  wake_hr
# 0  2025-03-14        63       57
#          date  sleep_hr  wake_hr
# 0  2025-03-13        67       53
#          date  sleep_hr  wake_hr
# 0  2025-03-12        63       49
#          date  sleep_hr  wake_hr
# 0  2025-03-11        70       60
#          date  sleep_hr  wake_hr
# 0  2025-03-10        68       65
#          date  sleep_hr  wake_hr
# 0  2025-03-09        69       51
#          date  sleep_hr  wake_hr
# 0  2025-03-08        65       55
#          date  sleep_hr  wake_hr
# 0  2025-03-07        72       50
#          date  sleep_hr  wake_hr
# 0  2025-03-06        61       55
#          date  sleep_hr  wake_hr
# 0  2025-03-05        58       44
#          date  sleep_hr  wake_hr
# 0  2025-03-04        50       51
#          date  sleep_hr  wake_hr
# 0  2025-03-03        62       45
#          date  sleep_hr  wake_hr
# 0  2025-03-02        56       49
#          date  sleep_hr  wake_hr
# 0  2025-03-01        63       48
# {'Date': datetime.date(2025, 2, 28), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 27), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 26), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 25), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 24), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 23), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 22), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 21), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 20), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 19), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 18), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 17), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 16), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 15), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 14), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 13), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 12), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 11), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 10), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 9), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 8), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 7), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 6), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 5), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 4), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 3), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 2), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 2, 1), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 31), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 30), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 29), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 28), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 27), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 26), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 25), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 24), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 23), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 22), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 21), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 20), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 19), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 18), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 17), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 16), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 15), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 14), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 13), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 12), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 11), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 10), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 9), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 8), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 7), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 6), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 5), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 4), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 3), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 2), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2025, 1, 1), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 31), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 30), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 29), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 28), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 27), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 26), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 25), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 24), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 23), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 22), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 21), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 20), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 19), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 18), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 17), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 16), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 15), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 14), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 13), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 12), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 11), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 10), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 9), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 8), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 7), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 6), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 5), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 4), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 3), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 2), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 12, 1), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 30), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 29), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 28), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 27), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 26), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 25), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 24), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 23), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 22), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 21), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 20), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 19), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 18), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 17), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 16), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 15), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 14), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 13), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 12), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 11), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 10), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 9), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 8), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 7), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 6), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 5), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 4), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 3), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 2), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 11, 1), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 31), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 30), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 29), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 28), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 27), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 26), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 25), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 24), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 23), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 22), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 21), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 20), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 19), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 18), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 17), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 16), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 15), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 14), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 13), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 12), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 11), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 10), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 9), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 8), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 7), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 6), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 5), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 4), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 3), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 2), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 10, 1), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 30), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 29), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 28), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 27), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 26), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 25), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 24), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 23), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 22), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 21), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 20), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 19), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 18), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 17), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 16), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 15), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 14), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 13), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 12), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 11), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 10), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 9), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 8), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 7), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 6), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 5), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 4), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 3), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 2), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 9, 1), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 31), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 30), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 29), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 28), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 27), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 26), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 25), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 24), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 23), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 22), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 21), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 20), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 19), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 18), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 17), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 16), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 15), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 14), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 13), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 12), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 11), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 10), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 9), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 8), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 7), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 6), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 5), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 4), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 3), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 2), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 8, 1), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 31), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 30), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 29), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 28), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 27), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 26), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 25), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 24), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 23), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 22), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 21), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 20), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 19), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 18), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 17), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 16), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 15), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 14), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 13), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 12), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 11), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 10), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 9), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 8), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 7), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 6), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 5), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 4), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 3), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 2), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 7, 1), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 6, 30), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 6, 29), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 6, 28), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 6, 27), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 6, 26), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 6, 25), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 6, 24), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 6, 23), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 6, 22), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 6, 21), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 6, 20), 'sleepHR': None, 'wakeHR': None}
# {'Date': datetime.date(2024, 6, 19), 'sleepHR': None, 'wakeHR': None}
#          date  sleep_hr  wake_hr
# 0  2025-07-14      56.0     50.0
# 1  2025-07-13      64.0     47.0
# 2  2025-07-12      61.0     45.0
# 3  2025-07-11      55.0     50.0
# 4  2025-07-10      56.0     45.0

# %%
update_query = text("""
    UPDATE simplesleepdata
    SET 
        "sleepHR" = :sleep_hr,
        "wakeHR" = :wake_hr
    WHERE date = :date
""")

with engine.connect() as conn:
    for _, row in df_sleepwakehr.iterrows():
        conn.execute(update_query, {
            "sleep_hr": row.get('sleep_hr', None),
            "wake_hr": row.get('wake_hr', None),
            "date": row['date'].strftime("%Y-%m-%d")
        })
    conn.commit()
